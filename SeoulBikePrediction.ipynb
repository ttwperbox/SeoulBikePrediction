# %%
import pandas as pd
import sklearn
from sklearn.tree import DecisionTreeRegressor

train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

test = test.fillna(0)
train = train.dropna()

X_train = train.drop(['count'], axis = 1)
Y_train = train['count']

model = DecisionTreeRegressor()
model.fit(X_train, Y_train)

pred = model.predict(test)

submission = pd.read_csv('data/submission.csv')
submission['count'] = pred
submission.to_csv('sub.csv', index = False)

# %%
# !git add *
# !git commit -m "predict complete"
# !git push
# Out:
# [master 6305a10] predict complete
#  2 files changed, 717 insertions(+)
#  create mode 100644 SeoulBikePrediction.ipynb
#  create mode 100644 sub.csv
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 3.78 KiB | 967.00 KiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# To https://github.com/ttwperbox/SeoulBikePrediction.git
#    116c175..6305a10  master -> master
